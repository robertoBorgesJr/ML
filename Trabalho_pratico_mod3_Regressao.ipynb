# %% [markdown]
# Trabalho prático do módulo 3 - Regressão

# %%
# importando as bibliotecas
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# acesso do colab ao google drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# carregamento do arquivo dataset
df = pd.read_csv('/content/gdrive/My Drive/IGTI/Aulas praticas/diabetes_numeric.csv')

# %%
# verifica as 5 primeiras linhas
df.head()
# Out:
#     age  deficit  c_peptide
# 0   5.2     -8.1        4.8
# 1   8.8    -16.1        4.1
# 2  10.5     -0.9        5.2
# 3  10.6     -7.8        5.5
# 4  10.4    -29.0        5.0

# %%
# Amostras (linhas) e features (colunas) do dataset
print('Amostras e features: ', df.shape)
# Out:
# Amostras e features:  (43, 3)

# %%
# Aqui dá pra ver que o tipo das colunas/features é 'object'
df.columns
# Out:
# Index(['age', 'deficit', 'c_peptide'], dtype='object')

# %%
# aqui vamos verificar se há dados faltantes
df.describe()

# como o count é igual a qtde de amostras em todas as features, então não há dados faltantes
# Out:
#              age    deficit  c_peptide
# count  43.000000  43.000000  43.000000
# mean    9.032558  -8.148837   4.746512
# std     4.022539   7.123080   0.720565
# min     0.900000 -29.000000   3.000000
# 25%     5.500000 -12.700000   4.450000
# 50%    10.400000  -7.800000   4.900000
# 75%    11.850000  -2.000000   5.100000
# max    15.600000  -0.200000   6.600000

# %%
# separa o label para a feature c_peptide em array
labels = np.array(df['c_peptide'])

# %%
# verificar pra que serve esse comando
feature_list = list(df.columns)

# %%
# remove a coluna c_peptide do dataset original
df = df.drop('c_peptide', axis = 1)

df.columns
# Out:
# Index(['age', 'deficit'], dtype='object')

# %%
# converte para array para trabalhar com os modelos
data = np.array(df)

# %%
# agora vamos dividir os dados em treino/teste
from sklearn.model_selection import train_test_split

train_data, test_data, train_labels, test_labels = train_test_split(data, labels, test_size = 0.25, random_state = 42)

# %%
# cria uma baseline com base em um modelo randomico de dados
#pula isso aqui por enqto
#baseline_preds = test_data[:, ]

# %% [markdown]
# **Aplica a regressão linear**

# %%
from sklearn.linear_model import LinearRegression

# treina o modelo de regressão linear
regression = LinearRegression().fit(train_data, train_labels)

# %%
# aplica o modelo
predictions1_labels = regression.predict(test_data)

# %%
# importar biblioteca para calculo de métricas
from sklearn import metrics

# %%
#criando a funcao para calculo do MAPE
def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
print('R2: ', metrics.r2_score(test_labels, predictions1_labels))
print('MAE: ', metrics.mean_absolute_error(test_labels, predictions1_labels))
print('MSE: ', metrics.mean_squared_error(test_labels, predictions1_labels))
#print('RMSE: ', np.sqrt(metrics.mean_squared_error(test_labels, predictions1_labels)))
#print('RMSLE: ', np.sqrt(metrics.mean_squared_log_error(test_labels, predictions1_labels)))
#print('MAPE: ', mean_absolute_percentage_error(test_labels, predictions1_labels))
# Out:
# R2:  0.21880597788432898
# MAE:  0.6107422323514548
# MSE:  0.474526947318197
